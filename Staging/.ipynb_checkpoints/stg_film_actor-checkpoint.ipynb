# %% [markdown]
# # Setup - Install Libraries

# %%
# Run the following commands once, in order to install libraries - DO NOT Uncomment this line.

# Uncomment below lines

#!pip3 install --upgrade pip
#!pip3 install google-cloud-bigquery
#!pip3 install pandas-gbq -U
#!pip3 install db-dtypes
#!pip3 install packaging --upgrade

# %%
# !pip3 install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (25.3)

# %%
# !pip3 install google-cloud-bigquery
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-cloud-bigquery in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (3.39.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.28.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery) (2.41.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery) (2.8.0)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery) (2.32.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.27.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.8.0)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.1)

# %%
# !pip3 install pandas-gbq -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas-gbq in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.32.0)
# Requirement already satisfied: setuptools in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (80.9.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (1.5.0)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (2.4.0)
# Requirement already satisfied: pandas<3.0.0,>=1.1.4 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (2.3.3)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (22.0.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (1.9.1)
# Requirement already satisfied: psutil>=5.9.8 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (7.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=2.15.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (2.28.1)
# Requirement already satisfied: google-auth>=2.14.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (1.2.3)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.20.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (3.39.0)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas-gbq) (25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.27.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth>=2.14.1->pandas-gbq) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth>=2.14.1->pandas-gbq) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth>=2.14.1->pandas-gbq) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.8.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.9.0.post0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.76.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.8.0)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (4.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rsa<5,>=3.1.4->google-auth>=2.14.1->pandas-gbq) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq) (3.3.1)

# %%
# !pip3 install db-dtypes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: db-dtypes in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from db-dtypes) (2.4.0)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from db-dtypes) (25.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from db-dtypes) (2.3.3)
# Requirement already satisfied: pyarrow>=13.0.0 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from db-dtypes) (22.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.3->db-dtypes) (1.17.0)

# %%
# !pip3 install packaging --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: packaging in c:\users\kotas\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (25.0)

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\kotas\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\\python.exe'

# %%
import pandas_gbq
print(pandas_gbq.__version__)
# Out:
# 0.32.0

# %% [markdown]
# # Import libraries

# %%
# Import libraries
from google.cloud import bigquery
import pandas as pd
from pandas_gbq import to_gbq
import os

print('Libraries imported successfully')
# Out:
# Libraries imported successfully

# %%
# Set the environment variable for Google Cloud credentials
# Place the path in which the .json file is located.

# Example (if .json is located in the same directory with the notebook)
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "at-arch-416714-6f9900ec7.json"

# -- YOUR CODE GOES BELOW THIS LINE
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/kotas/Documents/Corporate Data Analytics (course)/Capstone/data-analytics-corporate-ka-5fc0c27e0e73.json" # Edit path
# -- YOUR CODE GOES ABOVE THIS LINE

# %%
# Set your Google Cloud project ID and BigQuery dataset details

# -- YOUR CODE GOES BELOW THIS

project_id = 'data-analytics-corporate-ka' # Edit with your project id
dataset_id = 'staging_db' # Modify the necessary schema name: staging_db, reporting_db etc.
table_id = 'stg_film_actor' # Modify the necessary table name: stg_customer, stg_city etc.

# -- YOUR CODE GOES ABOVE THIS LINE

# %% [markdown]
# # SQL Query

# %%
# Create a BigQuery client
client = bigquery.Client(project=project_id)

# -- YOUR CODE GOES BELOW THIS LINE

# Define your SQL query here
query = """
with base as (
  select *
  from `data-analytics-corporate-ka.pagila_productionpublic.film_actor` --Your table path
  )

  , final as (
    select
        actor_id as film_actor_actor_id
    , film_id as film_actor_film_id
    , last_update as film_actor_last_update
   FROM base
  )

  select * from final
"""

# -- YOUR CODE GOES ABOVE THIS LINE

# Execute the query and store the result in a dataframe
df = client.query(query).to_dataframe()

# Explore some records
df.head()
# Out:
# C:\Users\kotas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    film_actor_actor_id  film_actor_film_id    film_actor_last_update
# 0                    1                  23 2022-02-15 10:05:03+00:00
# 1                    1                   1 2022-02-15 10:05:03+00:00
# 2                    1                 106 2022-02-15 10:05:03+00:00
# 3                    1                  25 2022-02-15 10:05:03+00:00
# 4                    1                 605 2022-02-15 10:05:03+00:00

# %% [markdown]
# # Write to BigQuery

# %%
# Define the full table ID
full_table_id = f"{project_id}.{dataset_id}.{table_id}"

# -- YOUR CODE GOES BELOW THIS LINE
# Define table schema based on the project description

schema = [
    bigquery.SchemaField('film_actor_actor_id', 'INTEGER'),
    bigquery.SchemaField('film_actor_film_id', 'INTEGER'),
    bigquery.SchemaField('film_actor_last_update', 'DATETIME'),
    ]

# -- YOUR CODE GOES ABOVE THIS LINE

# %%
# Create a BigQuery client
client = bigquery.Client(project=project_id)

# Check if the table exists
def table_exists(client, full_table_id):
    try:
        client.get_table(full_table_id)
        return True
    except Exception:
        return False

# Write the dataframe to the table (overwrite if it exists, create if it doesn't)
if table_exists(client, full_table_id):
    # If the table exists, overwrite it
    destination_table = f"{dataset_id}.{table_id}"
    # Write the dataframe to the table (overwrite if it exists)
    to_gbq(df, destination_table, project_id=project_id, if_exists='replace')
    print(f"Table {full_table_id} exists. Overwritten.")
else:
    # If the table does not exist, create it
    job_config = bigquery.LoadJobConfig(schema=schema)
    job = client.load_table_from_dataframe(df, full_table_id, job_config=job_config)
    job.result()  # Wait for the job to complete
    print(f"Table {full_table_id} did not exist. Created and data loaded.")
# Out:
# Table data-analytics-corporate-ka.staging_db.stg_film_actor did not exist. Created and data loaded.

# %%
# Below line converts your i.pynb file to .py python executable file. Modify the input and output names based
# on the table you are processing.
# Example:
# ! jupyter nbconvert stg_customer.ipynb --to python

# -- YOUR CODE GOES BELOW THIS LINE

# !python3 -m jupyter nbconvert stg_actor.ipynb --to python

# -- YOUR CODE GOES ABOVE THIS LINE
# Out:
# usage: jupyter.py [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                   [--paths] [--json] [--debug]
#                   [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# optional arguments:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands:
#
# Jupyter command `jupyter-nbconvert` not found.

# %%
# !python3 -m pip install nbconvert
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbconvert in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (7.16.4)
# Requirement already satisfied: beautifulsoup4 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (8.5.0)
# Requirement already satisfied: jinja2>=3.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.10.1)
# Requirement already satisfied: nbformat>=5.7 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (2.18.0)
# Requirement already satisfied: tinycss2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (1.4.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: webencodings in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6->nbconvert) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-core>=4.7->nbconvert) (4.3.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbclient>=0.5.0->nbconvert) (8.6.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert) (4.23.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert) (2.6)
# Requirement already satisfied: attrs>=22.2.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.4.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.15.0)

# %%
# !python3 -m pip install nbconvert -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbconvert in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (7.16.4)
# Requirement already satisfied: beautifulsoup4 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (8.5.0)
# Requirement already satisfied: jinja2>=3.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (0.10.1)
# Requirement already satisfied: nbformat>=5.7 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (2.18.0)
# Requirement already satisfied: tinycss2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (1.4.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: webencodings in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6->nbconvert) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-core>=4.7->nbconvert) (4.3.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbclient>=0.5.0->nbconvert) (8.6.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert) (4.23.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert) (2.6)
# Requirement already satisfied: attrs>=22.2.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /Users/antonesangelakes/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.4.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.15.0)
